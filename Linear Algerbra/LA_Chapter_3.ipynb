# %% [markdown]
# #  Determinants

# %% [markdown]
# Recall from previous section that a 2 × 2 matrix is invertible if and only if its determinant
# is nonzero.<br /> To extend this useful fact to larger matrices, we need a definition for the
# determinant of an n × n matrix.<br /> We can discover the definition for the 3 × 3 case by
# watching what happens when an invertible 3 × 3 matrix A is row reduced.

# %% [markdown]
# Consider A = [a<sub>ij</sub>]  with a<sub>11</sub> ≠ 0. If we multiply the second and third rows of A by
# a<sub>11</sub> and then subtract appropriate multiples of the first row from the other two rows, we
# find that A is row equivalent to the following two matrices:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Since A is invertible, either the (2, 2)-entry or the (3, 2)-entry on the right in (1) is
# nonzero. Let us suppose that the (2, 2)-entry is nonzero  (Otherwise, we can make a
# row interchange before proceeding.) Multiply row 3 by a<sub>11</sub>a<sub>22</sub> - a<sub>12</sub>a<sub>21</sub>,and then to the new row 3 add -(a<sub>11</sub>a<sub>32</sub> - a<sub>12</sub>a<sub>31</sub>) times row 2.

# %% [markdown]
#  This will show that:
#  ![image.png](attachment:image.png)

# %% [markdown]
# where:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Since A is invertible, Δ must be nonzero. The converse is true, too.<br />
# We call Δ in (2) the determinant of the 3 × 3 matrix A.

# %% [markdown]
# the determinant of a 2 × 2 matrix:
# ![image.png](attachment:image.png)

# %% [markdown]
# For a 1 × 1 matrix—say, A = [a<sub>11</sub>]—

# %% [markdown]
# To generalize the defintion of the determinant to larger matrices. we’ll use 2 × 2 determinants to rewrite the
# 3 × 3 determinant Δ described above.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For brevity, write:
# ![image.png](attachment:image.png)

# %% [markdown]
# where A<sub>11</sub>, A<sub>12</sub>, and A<sub>13</sub> are obtained from A by deleting the first row and one of the
# three columns.<br />
# For any square matrix A, let A<sub>ij</sub> denote the submatrix formed by deleting the ith row and j th column of A

# %% [markdown]
# For instance, if:
# ![image.png](attachment:image.png)

# %% [markdown]
# then A<sub>32</sub> is obtained by crossing out row 3 and column 2,

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can now give a recursive definition of a determinant.<br />
# When n = 3, det A is defined using determinants of the 2 × 2 submatrices A<sub>1j</sub>.<br />
# When n = 4, det A uses determinants of the 3 × 3 submatrices A<sub>1j</sub>.<br />
# In general, an n × n determinant is defined by determinants of (n - 1) × (n - 1) submatrices.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ● Compute the determinant of ![image.png](attachment:image.png)

# %% [markdown]
# <b>Solution:</b>![image.png](attachment:image.png)

# %% [markdown]
# Another common notation for the determinant of a matrix uses a pair of vertical
# lines in place of brackets.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To state the next theorem, it is convenient to write the definition of det A in a slightly
# different form.

# %% [markdown]
# Given A = [a<sub>ij</sub> ], the (i, j)-cofactor of A is the number C<sub>ij</sub> given by

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ● Use a cofactor expansion across the third row to compute det A, where ![image.png](attachment:image.png)

# %% [markdown]
# <b>Solution:</b> ![image.png](attachment:image.png)

# %% [markdown]
# ● Compute det A, where ![image.png](attachment:image.png)

# %% [markdown]
# <b>Solution:</b> ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###  PROPERTIES OF DETERMINANTS

# %% [markdown]
# The secret of determinants lies in how they change when row operations are performed.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ● Compute det A, where <br /> ![image.png](attachment:image.png)

# %% [markdown]
# <b>Solution:</b> The strategy is to reduce A to echelon form and then to use the fact that the
# determinant of a triangular matrix is the product of the diagonal entries. <br />
# The first two row replacements in column 1 do not change the determinant :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# An interchange of rows 2 and 3 reverses the sign of the determinant, so:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A common use of Theorem (c) in previuos theorem is to factor out a common
# multiple of one row of a matrix:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ● Compute det A, where:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>Solution:</b>  we factor out 2 from the top row, and then proceed
# with row replacements in the first column :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# adding 4 times row 2 to row 3:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Finally, adding -1/2 times row 3 to row 4, and computing the “triangular” determinant.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Suppose a square matrix A has been reduced to an echelon form U by row replacements and row interchanges.
# If there are r interchanges then:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Since U is in echelon form, it is triangular, and so detU is the product of the diagonal entries.<br />
# If A is invertible, the entries u<sub>i i</sub> (because
# A ~ I<sub>n</sub> and the u<sub>ii</sub> have not been scaled to 1’s) are all pivots

# %% [markdown]
# Otherwise, at least u<sub>nn</sub> is zero, and the product u<sub>11</sub> . . . u<sub>nn</sub> is zero.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# it is interesting to note that although the echelon form U described above is not unique
# (because it is not completely row reduced), and the pivots are not unique, the product
# of the pivots is unique, except for a possible minus sign.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Above Theorem adds the statement “det A ≠ 0” to the Invertible Matrix Theorem. A useful corollary is that det A = 0 when the columns of A are linearly dependent. <br />
# Also, det A = 0 when the rows of A are linearly dependent (Rows of A are columns of A<sup>T</sup>, and linearly dependent columns of A<sup>T</sup> make A<sup>T</sup> singular. When A<sup>T</sup> is singular, so is A, by the Invertible Matrix Theorem.)

# %% [markdown]
# ● Compute det A, where

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>Solution:</b> Add 2 times row 1 to row 3 to obtain

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Compute det A, where

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>Solution:</b> ![image.png](attachment:image.png)

# %% [markdown]
# An interchange of rows 2 and 3 would produce a “triangular determinant.” <br />
# Another approach is to make a cofactor expansion down the first column:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# However, det(A + B) is not equal to det A + det B, in general.
