# %% [markdown]
# ## Chapter 1 : Linear Equations

# %% [markdown]
# A <b>linear equation</b> in the variables x<sub>1</sub>, ... ,x<sub>n</sub> is an equation that can be written in the
# form: $$ a_1x_1 + a_2x_2 + \ldots + a_nx_n = b $$

# %% [markdown]
# where b and the coefficients a<sub>1</sub>,...,a<sub>n</sub> are real or complex numbers, usually known
# in advance.</br>
# The equations:
# $$ 4x_1 - 5x_2 = x_1x_2 \hspace{1em},\hspace{1em}  x_2 = 2\sqrt{x_1} - 6 $$
# are not linear because of the presence of x<sub>1</sub>x<sub>2</sub> in the first equation and √x in the second.</br>

# %% [markdown]
# A <b> system of linear equations</b> (or a linear system) is a collection of one or more
# linear equations involving the same variables.

# %% [markdown]
# A <b>solution</b> of the system is a list s<sub>1</sub>, s<sub>2</sub>, ...s<sub>n</sub> of numbers that makes each equation a
# true statement when the values s<sub>1</sub>,...s<sub>n</sub> are substituted for x<sub>1</sub>,...x<sub>n</sub>, respectively

# %% [markdown]
# The set of all possible solutions is called the <b>solution set</b> of the linear system.

# %% [markdown]
# Two linear systems are called <b>equivalent</b> if they have the same solution set.

# %% [markdown]
# Finding the solution set of a system of two linear equations in two variables is easy
# because it amounts to finding the intersection of two lines.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Of course, two lines need not intersect in a single point—they could be parallel, or
# they could coincide and hence “intersect” at every point on the line.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# A system of linear equations has: </br>
# 1. no solution, or
# 2. exactly one solution, or
# 3. infinitely many solutions.

# %% [markdown]
# A system of linear equations is said to be <b>consistent</b> if it has either one solution or
# infinitely many solutions; a system is <b>inconsistent</b> if it has no solution.

# %% [markdown]
# ### Matrix Notation

# %% [markdown]
# The essential information of a linear system can be recorded compactly in a rectangular
# array called a <b>matrix</b>.

# %% [markdown]
# $$ x_1 -  2x_2 + x_3 = 0 $$
# $$ \hspace{1.3em}   2x_2 - 8x_3 =  8 $$
# $$ 5x_1 \hspace{2em}   - x_3 = 10 $$
# with the coefficients of each variable aligned in columns, the matrix:
# \begin{bmatrix}
#     1 & -2 & 1 \\
#     0 & 2 & -8 \\
#     5 & 0 & -5 \\
# \end{bmatrix}

# %% [markdown]
# is called the <b> coefficient matrix </b>.

# %% [markdown]
# \begin{bmatrix}
#     1 & -2 & 1 & 0 \\
#     0 & 2 & -8 & 8 \\
#     5 & 0 & -5 & 10\\
# \end{bmatrix}
# is called the augmented matrix of the system.

# %% [markdown]
# Three basic operations are used to simplify a linear system:<br /> Replace one equation
# by the sum of itself and a multiple of another equation,<br /> interchange two equations, and
# multiply all the terms in an equation by a nonzero constant.

# %% [markdown]
# Keep x<sub>1</sub> in the first equation and eliminate it from the other equations. To do so, add -5 times equation 1 to equation 3 and multiply equation 2 by 1 in order to obtain 1 as the coefficient for x2.

# %% [markdown]
# \begin{bmatrix}
#     1 & -2 & 1 & 0 \\
#     0 & 1 & -4 & 4 \\
#     0 & 10 & -10 & 10\\
# \end{bmatrix}

# %% [markdown]
# Use the x<sub>2</sub> in equation 2 to eliminate the 10x<sub>2</sub> in equation 3.

# %% [markdown]
# \begin{bmatrix}
#     1 & -2 & 1 & 0 \\
#     0 & 1 & -4 & 4 \\
#     0 & 0 & 30 & -30\\
# \end{bmatrix}

# %% [markdown]
# Now, multiply equation 3 by 1
# 30 in order to obtain 1 as the coefficient for x3

# %% [markdown]
# \begin{bmatrix}
#     1 & -2 & 1 & 0 \\
#     0 & 1 & -4 & 4 \\
#     0 & 0 & 1 & -1\\
# \end{bmatrix}

# %% [markdown]
# use the x<sub>3</sub> in equation 3 first, to eliminate -4x and +x<sub>3</sub> terms in equations 2 and 1.

# %% [markdown]
# \begin{bmatrix}
#     1 & -2 & 0 & 1 \\
#     0 & 1 & 0 & 0 \\
#     0 & 0 & 1 & -1\\
# \end{bmatrix}

# %% [markdown]
# Now, having cleaned out the column above the x3 in equation 3, move back to the x2 in
# equation 2 and use it to eliminate the

# %% [markdown]
# \begin{bmatrix}
#     1 & 0 & 0 & 1 \\
#     0 & 1 & 0 & 0 \\
#     0 & 0 & 1 & -1\\
# \end{bmatrix}

# %% [markdown]
# It shows that the only solution of the original system is (1, 0, -1)

# %% [markdown]
# #### ELEMENTARY ROW OPERATIONS
# 1. (Replacement) Replace one row by the sum of itself and a multiple of another
# row.1
# 2. (Interchange) Interchange two rows.
# 3. (Scaling) Multiply all entries in a row by a nonzero constant

# %% [markdown]
# Two matrices are called <b>row equivalent</b> if there
# is a sequence of elementary row operations that transforms one matrix into the other. <br />
# It is important to note that row operations are reversible.

# %% [markdown]
# If the augmented matrices of two linear systems are row equivalent, then the two
# systems have the same solution set.

# %% [markdown]
# A <b>leading entry</b> of a row refers to the leftmost nonzero entry (in a nonzero row).<br />
# a <b>nonzero row or column</b> in a matrix means a row or column that contains at least one nonzero entry.

# %% [markdown]
# A rectangular matrix is in <b>echelon form</b> (or row echelon form) if it has the
# following two properties:
# 1. All nonzero rows are above any rows of all zeros.
# 2. All entries in a column below a leading entry are zeros.

# %% [markdown]
# If a matrix in echelon form satisfies the following additional conditions, then it is
# in <b>reduced echelon form</b> (or reduced row echelon form): <br /><br />
#  3. The leading entry in each nonzero row is 1.<br />
#  5. Each leading 1 is the only nonzero entry in its column

# %% [markdown]
# echelon form :\begin{bmatrix}
#     2 & -3 & 2 & 1 \\
#     0 & 1 & -4 & 8 \\
#     0 & 0 & 0 & 5/2\\
# \end{bmatrix}

# %% [markdown]
# reduced echelon form:
# \begin{bmatrix}
#     1 & 0 & 0 & 29 \\
#     0 & 1 & 0 & 16 \\
#     0 & 0 & 0 & 3 \\
# \end{bmatrix}

# %% [markdown]
# #### Uniqueness of the Reduced Echelon Form
# Each matrix is row equivalent to one and only one reduced echolem matrix.

# %% [markdown]
# If a matrix A is row equivalent to an echelon matrix U, we call U <b>an echelon form</b>
# (or row echelon form) of A; if U is in reduced echelon form, we call U the <b>reduced
# echelon form</b> of A.

# %% [markdown]
# When row operations on a matrix produce an echelon form, further row operations to
# obtain the reduced echelon form do not change the positions of the leading entries. Since
# the reduced echelon form is unique

# %% [markdown]
# <i>the leading entries are always in the same positions
# in any echelon form obtained from a given matrix</i>

# %% [markdown]
# A <b>pivot position</b> in a matrix A is a location in A that corresponds to a leading 1
# in the reduced echelon form of A. A pivot column is a column of A that contains
# a pivot position

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### The Row Reduction Algorithm

# %% [markdown]
# #### step 1

# %% [markdown]
# Begin with the leftmost nonzero column. This is a pivot column. The pivot
# position is at the top.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### step 2
# Select a nonzero entry in the pivot column as a pivot. If necessary, interchange
# rows to move this entry into the pivot position.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### step 3
# Use row replacement operations to create zeros in all positions below the pivot.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### step 4
# Cover (or ignore) the row containing the pivot position and cover all rows, if any,
# above it. Apply steps 1–3 to the submatrix that remains. Repeat the process until
# there are no more nonzero rows to modify.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### step 5
# Beginning with the rightmost pivot and working upward and to the left, create
# zeros above each pivot. If a pivot is not 1, make it 1 by a scaling operation.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The combination of steps 1–4 is called the <b>forward phase</b> of the row reduction
# algorithm. <br />
# Step 5, which produces the unique reduced echelon form, is called the <b>backward phase</b>.

# %% [markdown]
# Suppose, for example, that the augmented matrix of a linear system has been
# changed into the equivalent reduced echelon form:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The variables x1 and x2 corresponding to pivot columns in the matrix are called <b>basic variables</b>.<br />
# The other variable, x3, is called a <b>free variable</b>.

# %% [markdown]
# the solution set can be described
# explicitly by solving the reduced system of equations for the basic variables in terms of
# the free variables.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <i>Each different
# choice of x3 determines a (different) solution of the system, and every solution of the
# system is determined by a choice of x3.</i>

# %% [markdown]
# Determine the existence and uniqueness of the solutions to the system:
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The basic variables are x<sub>1</sub>, x<sub>2</sub>, and x<sub>5</sub>; the free variables are x<sub>3</sub> and x<sub>4</sub>.<br /> Also, the solution is not unique because there are free variables. Each different
# choice of x<sub>3</sub> and x<sub>4</sub> determines a different solution.

# %% [markdown]
# Row reduce the system’s augmented matrix:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This echelon matrix shows that the system is inconsistent, because its rightmost
# column is a pivot column; the third row corresponds to the equation 0 = 5.

# %% [markdown]
# ### Existence and Uniqueness Theorem

# %% [markdown]
# A linear system is consistent if and only if the rightmost column of the augmented
# matrix is not a pivot column—that is, if and only if an echelon form of the
# augmented matrix has no row of the form $$ [0, ... ,0] $$ with b nonzero.<br />
# If a linear system is consistent, then the solution set contains either (i) a unique
# solution, when there are no free variables, or (ii) infinitely many solutions, when
# there is at least one free variable

# %% [markdown]
# ### Vectors in R<sup>2</sup>

# %% [markdown]
# A matrix with only one column is called a <b>column vector</b>, or simply a <b>vector</b>. Examples
# of vectors with two entries are :

# %% [markdown]
# $$
# u = \begin{bmatrix}
#     3  \\
#     -1\\
# \end{bmatrix}
# \quad
# v = \begin{bmatrix}
#     .2  \\
#     .3\\
# \end{bmatrix}
# $$

# %% [markdown]
# The R stands for the real numbers that appear as entries in the
# vectors, and the exponent 2 indicates that each vector contains two entries.<br />
# Two vectors in R<sup>2</sup>
# are <b>equal</b> if and only if their corresponding entries are equal.

# %% [markdown]
# Given two vectors <b>u</b> and <b>v</b> in R<sup>2</sup>
# , their sum is the vector <b>u</b> + <b>v</b> obtained by adding
# corresponding entries of <b>u</b> and <b>v</b>. For example:
# ![image.png](attachment:image.png)

# %% [markdown]
# Given a vector <b>u</b> and a real number c, the scalar multiple of <b>u</b> by c is the vector c<b>u</b>
# obtained by multiplying each entry in <b>u</b> by c. For instance:
# ![image.png](attachment:image.png)

# %% [markdown]
# The number c in c<b>u</b> called a scalar; it is written in lightface type to distinguish it from
# the boldface vector <b>u</b>.

# %% [markdown]
# Consider a rectangular coordinate system in the plane. Because each point in the plane
# is determined by an ordered pair of numbers, we can identify a geometric point (a, b) with the column vector :
# $$  \begin{bmatrix}
#     a  \\
#     b \\
# \end{bmatrix}
# $$
# So we may regard R2
# as the set of all points in the plane:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Parallelogram Rule for Addition
# <div style="background-color: #f0f8ff; padding: 10px;">
#     If <b>u</b> and <b>v</b> in R<sup>2</sup>
# are represented as points in the plane,<br /> then <b>u</b> + <b>v</b> corresponds to
# the fourth vertex of the parallelogram whose other vertices are <b>u</b>, <b>0</b>, and <b>v</b>.
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Vectors in R<sup>3</sup>

# %% [markdown]
# Vectors in R<sup>3</sup>are 3 * 1 column matrices with three entries. They are represented geometrically by points in a three-dimensional coordinate space, with arrows from the
# Scalar multiples.
# origin sometimes included for visual clarity. <br />
# The vectors
# $$
# a = \begin{bmatrix}
#     2  \\
#     3  \\
#     4
# \end{bmatrix}
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Vectors in R<sup>n</sup>

# %% [markdown]
# If n is a positive integer, R<sup>n</sup>
# (read “r-n”) denotes the collection of all lists (or ordered
# n-tuples) of n real numbers, usually written as n*1 column matrices, such as

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The vector whose entries are all zero is called the zero vector and is denoted by <b>0</b>.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Given vectors v<sub>1</sub>, v<sub>2</sub>, ... ,v<sub>p</sub> R<sup>n</sup>
# and given scalars c<sub>1</sub>, c<sub>2</sub>, ... , c<sub>n</sub> the vector <b>y</b> defined
# by:![image.png](attachment:image.png)
# is called a linear combination of v<sub>1</sub>, v<sub>2</sub>, ... ,v<sub>p</sub> with weights c<sub>1</sub>, c<sub>2</sub>, ... , c<sub>n</sub><br />
# The weights in
# a linear combination can be any real numbers, including zero.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# One of the key ideas in linear algebra is to study the set of all vectors that can be
# generated or written as a linear combination of a fixed set of {v<sub>1</sub>, ... ,v<sub>p</sub>} of vectors.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Asking whether a vector <b>b</b> is in Span {v<sub>1</sub>, ... ,v<sub>p</sub>} amounts to asking whether the
# vector equation ![image.png](attachment:image.png)
# has a solution, or, equivalently, asking whether the linear system with augmented matrix  $$ [v_1  ... v_p  b] $$

# %% [markdown]
# ### A Geometric Description of Span {v} and Span {u, v}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## The matrix Equation Ax=b

# %% [markdown]
# A fundamental idea in linear algebra is to view a linear combination of vectors as the
# product of a matrix and a vector.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Note that A<b>x</b> is defined only if the number of columns of A equals the number of entries
# in <b>x</b>

# %% [markdown]
# ![image.png](attachment:image.png)
# is equivalent to:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# the linear combination on the left side is a matrix times a vector, so
# that becomes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Above Equation has the form A<b>x</b> = <b>b</b>. Such an equation is called a <b>matrix equation</b><br />
# Similar calculations show that any system of linear equations, or any vector equation, can be written as an equivalent matrix equation in the form A<b>x</b> = <b>b</b>.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Theorem above provides a powerful tool for gaining insight into problems in linear
# algebra, because a system of linear equations may now be viewed in three different
# but equivalent ways: as a matrix equation, as a vector equation, or as a system of linear
# equations. Whenever you construct a mathematical model of a problem in real life, you
# are free to choose whichever viewpoint is most natural. Then you may switch from one
# formulation of a problem to another whenever it is convenient. In any case, the matrix
# equation, the vector equation, and the system of equations are all solved in the
# same way—by row reducing the augmented matrix.

# %% [markdown]
# #### Existence of Solutions
# The definition of A<b>x</b> leads directly to the following useful fact:

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# In the next theorem, the sentence “The columns of A span R<sup>m</sup>” means that every <b>b</b> in R<sup>m</sup> is a linear combination of the columns of A. <br/>  In general, a set of vectors {v<sub>1</sub>, ... ,v<sub>p</sub>} in R<sup>m</sup> spans (or generates) R<sup>m</sup> if every vector in R<sup>m</sup> is a linear combination of
# v<sub>1</sub>, ... ,v<sub>p</sub> —that is, if Span {v<sub>1</sub>, ... ,v<sub>p</sub>} = R<sub>m</sub>.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Statements (a), (b), and
# (c) are equivalent because of the definition of Ax and what it means for a set of vectors
# to span R<sup>m</sup>. <br />

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# By definition, the matrix in last Example with 1’s on the diagonal and 0’s elsewhere
# is called an <b>identity matrix</b> and is denoted by <b><i>I</i></b>.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### SOLUTION SETS OF LINEAR SYSTEMS

# %% [markdown]
# #### Homogeneous Linear Systems

# %% [markdown]
# A system of linear equations is said to be homogeneous if it can be written in the form
# A<b>x</b> = <b>0</b>, where A is an m * n matrix and <b>0</b> is the zero vector in R<sup>m</sup>.<br />
# Such a system A<b>x</b> = <b>0</b> always has at least one solution, namely, <b>x</b> = <b>0</b> (the zero vector in R<sub>n</sub>). This zero solution is usually called the trivial solution.<br />
#  For a given equation A<b>x</b> = <b>0</b> the important question is whether there exists a nontrivial solution. That is, a nonzero vector <b>x</b> that satisfies A<b>x</b> = <b>0</b>.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ● Determine if the following homogeneous system has a nontrivial solution:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# Since x<sub>3</sub> is a free variable, A<b>x</b> = <b>0</b> has nontrivial solutions.

# %% [markdown]
# ![image.png](attachment:image.png)
# the general solution of A<b>x</b> = <b>0</b> has the form:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here x<sub>3</sub> is factored out of the expression for the general solution vector. This shows that
# every solution of A<b>x</b> = <b>0</b> in this case is a scalar multiple of <b>v</b>.<br /> The trivial solution is
# obtained by choosing x<sub>3</sub> = 0.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ● A single linear equation can be treated as a very simple system of
# equations. Describe all solutions of the homogeneous “system” :
# ![image.png](attachment:image.png)

# %% [markdown]
# There is no need for matrix notation. Solve for the basic variable x<sub>1</sub> in
# terms of the free variables:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This calculation shows that every solution of equation is a linear combination of the vectors
# <b>u</b> and <b>v</b>, shown above. That is, the solution set is Span {u, v}. <br />
# Since neither <b>u</b> nor <b>v</b> is a scalar multiple of the other, the solution set is a plane through the origin:
# ![image.png](attachment:image.png)

# %% [markdown]
# The fact that the solution set of a homogeneous equation A<b>x</b> = <b>0</b> can always be expressed explicitly as
# Span {v<sub>1</sub>, ... , v<sub>p</sub>} for suitable vectors v<sub>1</sub>, ... , v<sub>p</sub> <br />
# If the only solution is the zero vector,
# then the solution set is Span {<b>0</b>}.<br />
# If the equation A<b>x</b> = <b>0</b> has only one free variable, the solution set is a line through the origin.<br />
# A plane through the origin, when there are two or more free variables.

# %% [markdown]
# The solution set shown in the last example is called <b>parametric vector equation </b> of the plane. Sometimes such an equation is written as:
# ![image.png](attachment:image.png)
# and for the line <b>x</b> = x<sub>3</sub><b>v</b> (with x<sub>3</sub> free), or  <b>x</b> = t<b>v</b> (with t in R).

# %% [markdown]
# #### Solutions of Nonhomogeneous Systems
# When a nonhomogeneous linear system has many solutions, the general solution can be
# written in parametric vector form as one vector plus an arbitrary linear combination of
# vectors that satisfy the corresponding homogeneous system.

# %% [markdown]
# ● Describe all solutions of A<b>x</b> = <b>b</b>, where:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# The equation <b>x</b> = <b>p</b> + x<sub>3</sub><b>v</b>, or, writing t as a general parameter,
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Thus the solutions of A<b>x</b> = <b>b</b> are obtained by
# adding the vector <b>p</b> to the solutions of A<b>x</b> = <b>0</b>.<br />
# The vector <b>p</b> itself is just one particular solution of A<b>x</b> = <b>b</b>.
# ![image.png](attachment:image.png)

# %% [markdown]
# To describe the solution set of A<b>x</b> = <b>b</b> geometrically, we can think of vector
# addition as a translation.<br />
# Given <b>v</b> and <b>p</b> in R<sup>2</sup> or R<sup>3</sup>
# , the effect of adding <b>p</b> to <b>v</b> is
# to move <b>v</b> in a direction parallel to the line through <b>p</b> and <b>0</b><br />
# We say that <b>v</b> is translated by <b>p</b> to <b>v</b> + <b>p</b>. ![image.png](attachment:image.png)

# %% [markdown]
# Thus
# the solution set of A<b>x</b> = <b>b</b> is a line through <b>p</b> parallel to the solution set of A<b>x</b> = <b>0</b>.
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# The solution set generalizes to any consistent equation A<b>x</b> = <b>b</b>, although the solution set will be larger
# than a line when there are several free variables.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Theorem above says that if A<b>x</b> = <b>b</b> has a solution, then the solution set is obtained by
# translating the solution set of A<b>x</b> = <b>b</b>, using any particular solution <b>p</b> of A<b>x</b> = <b>b</b> for
# the translation.<br />
# Figure below illustrates the case in which there are two free variables:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ● Each of the following equations determines a plane in R<sup>3</sup>. Do the two planes intersect? If so, describe their intersection:
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>Solution:</b><br/>
# Row reduce the augmented matrix:![image.png](attachment:image.png)

# %% [markdown]
# The general solution in parametric
# vector form is:
# ![image.png](attachment:image.png)
# The intersection of the two planes is the line through p in the direction of <b>v</b>.

# %% [markdown]
# ### LINEAR INDEPENDENCE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Equation (2) is called a <b>linear dependence relation</b> among v<sub>1</sub>, ... , v<sub>p</sub> when the
# weights are not all zero.<br />
# An indexed set is linearly dependent if and only if it is not linear independent.

# %% [markdown]
# ● Determine if the set {<b>v</b><sub>1</sub>, <b>v</b><sub>2</sub> ,<b>v</b><sub>3</sub>} is linearly independent
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
# ![image-2.png](attachment:image-2.png)
# Clearly, x<sub>1</sub> and x<sub>2</sub> are basic variables, and x<sub>3</sub> is free. Each nonzero value of x<sub>3</sub>
# determines a nontrivial solution. Hence v<sub>1</sub>, v<sub>2</sub>, v<sub>3</sub> are linearly dependent (and
# not linearly independent)

# %% [markdown]
# #### Linear Independence of Matrix Columns

# %% [markdown]
# The matrix equation A<b>x</b> = <b>0</b> can be written as:
# ![image-2.png](attachment:image-2.png)
# Each linear dependence relation among the columns of A corresponds to a nontrivial
# solution of A<b>x</b> = <b>0</b>.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ● Determine if the columns of the matrix A are linearly independent.
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
# ![image.png](attachment:image.png)
# At this point, it is clear that there are three basic variables and no free variables.<br />
# So the equation A<b>x</b> = <b>0</b> has only the trivial solution, and the columns of A are linearly independent.

# %% [markdown]
# #### Sets of One or Two Vectors

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In geometric terms, two vectors are linearly dependent if and only if they lie on the
# same line through the origin:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Sets of Two or More Vectors

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ●  Describe the set spanned by <b>u</b> and <b>v</b> and explain why a vector <b>w</b> is in Span {<b>u</b>, <b>v</b>} if and only if {<b>u</b>, <b>v</b>, <b>w</b>} is linearly dependent
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:<br />
# The vectors <b>u</b> and <b>v</b> are linearly independent because neither vector is
# a multiple of the other, and so they span a plane in R<sup>3</sup>.<br />
# If <b>w</b> is a linear combination of <b>u</b> and <b>v</b>, then {<b>u</b>, <b>v</b>, <b>w</b>} is linearly dependent<br />
# Conversely, suppose that {<b>u</b>, <b>v</b>, <b>w</b>} is linearly dependent.By Above Theorem, some vector in {<b>u</b>, <b>v</b>, <b>w</b>} is a linear combination of the preceding vectors <br />
# That vector must be <b>w</b>, since <b>v</b> is not a multiple of <b>u</b>. So <b>w</b> is in Span {<b>u</b>, <b>v</b>}
# ![image.png](attachment:image.png)
# The set {<b>u</b>, <b>v</b>, <b>w</b>} will be linearly dependent if and only if <b>w</b> is in the plane spanned by <b>u</b> and <b>v</b>.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ● Determine by inspection if the given set is linearly dependent.

# %% [markdown]
# ![image.png](attachment:image.png)
# a. The set contains four vectors, each of which has only three entries. So the set is
# linearly dependent.<br />
# b. Since the zero vector is in the set, the set is linearly dependent.
