# %% [markdown]
# ## Chapter 4: Vector spaces

# %% [markdown]
# ###  VECTOR SPACES AND SUBSPACES

# %% [markdown]
# The specific properties of interest are listed in the following
# definition.<br />
# ![image.png](attachment:image.png)

# %% [markdown]
# Using only these axioms, one can show that the zero vector in Axiom 4 is unique,<br />
# and the vector -<b>u</b>, called the <b>negative</b> of <b>u</b>, Axiom 5 is unique for each <b>u</b> in V

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ● The spaces R<sup>n</sup>, where n ≥ 1, are the premier examples of vector spaces.

# %% [markdown]
# ● Let V be the set of all arrows (directed line segments) in three dimensional space, with two arrows regarded as equal if they have the same length and point in the same direction.<br /> Define addition by the parallelogram rule. and for each <b>v</b> in V , define c<b>v</b> to be the arrow whose length is |c| times the length of
# <b>v</b>, pointing in the same direction as <b>v</b> if c ≥ 0 and otherwise pointing in the opposite
# direction. <br />
# Show that V is a vector space. This space is a common model in physical problems for various forces

# %% [markdown]
# <b>Solution :</b> The definition of V is geometric, using concepts of length and direction. No xyz-coordinate system is involved.<br />
# An arrow of zero length is a single point and represents the zero vector. The negative of <b>v</b> is (-1) <b>v</b>. So Axioms 1, 4, 5, 6, and 10 are
# evident.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ● Let S be the space of all doubly infinite sequences of numbers (usually
# written in a row rather than a column):

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If {z<sub>k</sub>} is another element of S, then the sum {y<sub>k</sub>} + {z<sub>k</sub>} is the sequence {y<sub>k</sub> + z<sub>k</sub>}
# formed by adding corresponding terms of  {y<sub>k</sub>} and {z<sub>k</sub>}. <br /> The scalar multiple c{y<sub>k</sub>} is
# the sequence {cy<sub>k</sub>}.

# %% [markdown]
# ● For n ≥ 0, the set P<sub>n</sub> of polynomials of degree at the most n consists of all polynomials of the form

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# where the coefficients a<sub>0</sub> ,  . . . , a<sub>n</sub> and the variable t are real numbers. The degree of
# p is the highest power of t in (4) whose coefficient is not zero.<br />
# If p(t) = a<sub>0</sub> ≠ 0 , the degree of p is zero. If all the coefficients are zero, p is called the zero polynomial. The
# zero polynomial is included in P<sub>n</sub> even though its degree, for technical reasons, is not defined.<br />
# if q(t) = b<sub>0</sub> + b<sub>1</sub>t + . . . + b<sub>n</sub>t<sup>n</sup> then the sum p + q is defined by <br /> ![image.png](attachment:image.png)

# %% [markdown]
# The scalar multiple cp is the polynomial defined by: <br /> ![image.png](attachment:image.png)

# %% [markdown]
# ● Let V be the set of all real-valued functions defined on a set D.<br /> Functions are added
# in the usual way: f + g is the function whose value at t in the domain D is f(t) + g(t).<br />
# Likewise, for a scalar c and an f in V , the scalar multiple cf is the function whose value at t is cf(t).

# %% [markdown]
# ### Subspaces

# %% [markdown]
# In many problems, a vector space consists of an appropriate subset of vectors from some
# larger vector space. In this case, only three of the ten vector space axioms need to be
# checked; the rest are automatically satisfied.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Properties (a), (b), and (c) guarantee that a subspace H of V is itself a vector
# space, under the vector space operations already defined in V .<br /> To verify this, note
# that properties (a), (b), and (c) are Axioms 1, 4, and 6. Axioms 2, 3, and 7–10 are
# automatically true in H because they apply to all elements of V , including those in H. <br />
# Axiom 5 is also true in H, because if u is in H, then (-1) u is in H by property (c), and
# we know from equation (3) earlier in this section that (-1) u is the vector -u in Axiom 5.

# %% [markdown]
# So every subspace is a vector space. Conversely, every vector space is a subspace.<br />
# The term subspace is used when at least
# two vector spaces are in mind, with one inside the other, and the phrase subspace of V
# identifies V as the larger space

# %% [markdown]
# ● The set consisting of only the zero vector in a vector space V is a subspace of V , called the <b>zero subspace</b> and written as {<b>0</b>}

# %% [markdown]
# ● Let P be the set of all polynomials with real coefficients, with operations in P defined as for functions. Then P is a subspace of the space of all real-valued
# functions defined on R.

# %% [markdown]
# ● The vector space R<sup>2</sup> is not a subspace of R<sup>3</sup> because R<sup>2</sup> is not even a subset of R<sup>3</sup>.<br />
# The set:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# is a subset of R<sup>3</sup>. Show that H is a subspace of R<sup>3</sup>

# %% [markdown]
# <b>Solution: </b> The zero vector is in H, and H is closed under vector addition and scalar
# multiplication because these operations on vectors in H always produce vectors whose
# third entries are zero (and so belong to H ). Thus H is a subspace of R<sup>3</sup>.

# %% [markdown]
# ● A plane in R<sup>3</sup> not through the origin is not a subspace of R<sup>3</sup>, because the plane does not contain the zero vector of R3. Similarly, a line in R2 not through the origin, such as in Figure 8, is not a subspace of R<sup>2</sup>

# %% [markdown]
# ### A Subspace Spanned by a Set

# %% [markdown]
# The term <b>linear combination</b> refers to any sum of scalar multiples of
# vectors, and Span {<b>v<sub>1</sub></b> , . . . , <b>v<sub>p</sub></b>} denotes the set of all vectors that can be written as linear
# combinations of <b>v<sub>1</sub></b> , . . . , <b>v<sub>p</sub></b>.

# %% [markdown]
# ● Given <b>v<sub>1</sub></b> and <b>v<sub>2</sub></b> in a vector space V , let H = Span {<b>v<sub>1</sub></b> , <b>v<sub>1</sub>}</b>. Show that H is a subspace of V.

# %% [markdown]
# The zero vector is in H, since <b>0</b> = 0<b>v<sub>1</sub></b> + 0<b>v<sub>2</sub></b>.To show that H is closed under vector addition, take two arbitrary vectors in H, say,

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# By Axioms 2, 3, and 8 for the vector space V ,

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So u C w is in H. Furthermore, if c is any scalar, then by Axioms 7 and 9,

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# which shows that cu is in H and H is closed under scalar multiplication. Thus H is a
# subspace of V

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ● Let H be the set of all vectors of the form (a - 3b, b - a, a, b) where a and b are arbitrary scalars. Show that H is a subspace of R<sup>4</sup>.

# %% [markdown]
# <b>Solution :</b> Write the vectors in H as column vectors. Then an arbitrary vector in H
# has the form

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This calculation shows that H = Span {<b>v<sub>1</sub></b>, <b>v<sub>2</sub></b>}, where <b>v<sub>1</sub></b> and <b>v<sub>2</sub></b> are the vectors indicated above. Thus H is a subspace of R<sup>4</sup>.

# %% [markdown]
# ### The Null Space of a Matrix

# %% [markdown]
# Consider the following system of homogeneous equations:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In matrix form, this system is written as A<b>x</b> = <b>0</b>, where

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Recall that the set of all <b>x</b> that satisfies the equation is called the solution set of the system. <br />
# We call the set of x that satisfy A<b>x</b> = <b>0</b> the <b>null space</b> of the matrix A.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A  more dynamic description of Nul A is the set of all <b>x</b> in R<sup>n</sup> that are mapped into the zero vector of R<sup>m</sup> via the linear transformation <b>x</b> => A<b>x</b>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ● let A be above and <b>u</b> following, determine if <b>u</b> belongs to the null space of A:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>Solution</b>:   ![image.png](attachment:image.png) <br />
# Thus <b>u</b> is in Nul A.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### An Explicit Description of Nul A

# %% [markdown]
# There is no obvious relation between vectors in Nul A and the entries in A. We say that
# Nul A is defined implicitly, because it is defined by a condition that must be checked.<br />
# No explicit list or description of the elements in Nul A is given.<br /> However, solving
# the equation A<b>x</b> = <b>0</b> amounts to producing an explicit description of Nul A.

# %% [markdown]
# ● Find a spanning set for the null space of the matrix:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The first step is to find the general solution of A<b>x</b> = <b>0</b> in terms of free variables.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  Next, decompose the vector giving the general solution into a linear combination
# of vectors where the weights are the free variables![image.png](attachment:image.png)

# %% [markdown]
# Every linear combination of <b>u</b>, <b>v</b>, and <b>w</b> is an element of Nul A and vice versa. Thus
# {<b>u</b>, <b>v</b>, <b>w</b>} is a spanning set for Nul A

# %% [markdown]
# ### The Column Space of a Matrix

# %% [markdown]
# Another important subspace associated with a matrix is its column space. Unlike the
# null space, the column space is defined explicitly via linear combinations.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Since Span {a<sub>1</sub>, ... , a<sub>n</sub>} is a subspace, by Theorem 1, the next theorem follows from
# the definition of Col A and the fact that the columns of A are in R<sup>m</sup>.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Note that a typical vector in Col A can be written as A<b>x</b> for some <b>x</b> because the notation A<b>x</b> stands for a linear combination of the columns of A. That is

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Recall that the columns of A span R<sup>m</sup> if and only if the equation A<b>x</b> = <b>b</b> has a solution for each <b>b</b>.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The Contrast Between Nul A and Col A

# %% [markdown]
# ● Let ![image.png](attachment:image.png)

# %% [markdown]
# a. If the column space of A is a subspace of R<sup>k</sup> , what is k? <br />
# b. If the null space of A is a subspace of R<sup>k</sup>, what is k?

# %% [markdown]
# <b>Solution:</b> <br />
# a. The columns of A each have three entries, so Col A is a subspace of R<sup>k</sup>, where k = 3 <br />
# b. A vector <b>x</b> such that A<b>x</b> is defined must have four entries, so Nul A is a subspace of R<sup>k</sup>, where k = 4.

# %% [markdown]
# When a matrix is not square, as in above example, the vectors in Nul A and Col A live
# in entirely different “universes.”<br /> For example, no linear combination of vectors in R<sup>3</sup>
# can produce a vector in R<sup>3</sup>.<br />
# When A is square, Nul A and Col A do have the zero vector
# in common, and in special cases it is possible that some nonzero vectors belong to both
# Nul A and Col A.

# %% [markdown]
# ● With A as in above, find a nonzero vector in Col A and a nonzero vector in Nul A.

# %% [markdown]
# It is easy to find a vector in Col A. Any column of A will do, say: ![image.png](attachment:image.png)

# %% [markdown]
# To find a nonzero vector in Nul A, row reduce the augmented matrix:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Thus, if <b>x</b> satisfies A<b>x</b> = <b>0</b>, then x<sub>1</sub> = <b>0</b>, then x<sub>1</sub> = -9x<sub>3</sub>, x<sub>2</sub> = 5x<sub>3</sub>, x<sub>4</sub> = 0, and x<sub>3</sub> is free. <br />
# Assigning a nonzero value to x<sub>3</sub>—say, x<sub>3</sub> = 1—we obtain a vector in Nul A, namely,
# x = (-9, 5, 1, 0).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Kernel and Range of a Linear Transformation

# %% [markdown]
# Subspaces of vector spaces other than R<sup>n</sup> are often described in terms of a linear transformation instead of a matrix.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The <b>kernel</b> (or <b>null space</b>) of such a T is the set of all <b>u</b> in V such that T(<b>u</b>) = <b>0</b>
# (the zero vector in W). <br /> The <b>range</b> of T is the set of all vectors in W of the form T(<b>x</b>)
# for some <b>x</b> in V .<br /> If T happens to arise as a matrix transformation—say, T(x) = A<b>x</b>
# for some matrix A—then <br /> the kernel and the range of T are just the null space and the
# column space of A, as defined earlier.

# %% [markdown]
# ![image.png](attachment:image.png)
